# %% [markdown]
# **PERCEPTRON SIMPLE**
#
# *presentado por:*
#
# Andrés Felipe Alvarez Cortes
#
# Juan David Oquendo Usuga
#
# Camila Suárez Osorio

# %%
import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# %%
X, y = datasets.make_blobs(n_samples=150,n_features=2, 
                           centers=2,cluster_std=2.5, 
                           random_state=2)
# Dividir train / test
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
epochs = 100
clf = Perceptron(max_iter=1, tol=None, warm_start=True)

costs = []
accuracies = []

for epoch in range(epochs):
    clf.fit(X_train, y_train)

    # costo: número de errores de clasificación
    y_pred_train = clf.predict(X_train)
    errores = np.sum(y_pred_train != y_train)
    costs.append(errores)

    # accuracy por época
    acc = accuracy_score(y_train, y_pred_train)
    accuracies.append(acc)

# %%
print("Pesos (W):", clf.coef_)
print("Bias (b):", clf.intercept_)
# Out:
# Pesos (W): [[ 8.60756105 13.11077405]]
# Bias (b): [78.]

# %%
y[y==0]=-1
fig = plt.figure(figsize=(10,8))
plt.plot(X[:, 0][y == -1], X[:, 1][y == -1], 'r^')
plt.plot(X[:, 0][y == 1], X[:, 1][y == 1], 'bs')
plt.xlabel("feature 1")
plt.ylabel("feature 2")
plt.title('Random Classification Data with 2 classes')
# Out:
# Text(0.5, 1.0, 'Random Classification Data with 2 classes')

# %%
plt.plot(costs)
plt.xlabel("Epochs")
plt.ylabel("Costo (errores de clasificación)")
plt.title("Costo vs Epochs")
plt.show()

# %%
y[y==0]=-1
fig = plt.figure(figsize=(10,8))
plt.plot(X[:, 0][y == -1], X[:, 1][y == -1], 'r^')
plt.plot(X[:, 0][y == 1], X[:, 1][y == 1], 'bs')
plt.xlabel("feature 1")
plt.ylabel("feature 2")
plt.title('Random Classification Data with 2 classes')
# Out:
# Text(0.5, 1.0, 'Random Classification Data with 2 classes')

# %%
plt.plot(accuracies)
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Accuracy vs Epochs")
plt.show()

# %%
y_pred = clf.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("F1-score:", f1_score(y_test, y_pred))
print("\nMatriz de Confusión:\n", confusion_matrix(y_test, y_pred))
print("\nReporte de Clasificación:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 1.0
# F1-score: 1.0
#
# Matriz de Confusión:
#  [[18  0]
#  [ 0 27]]
#
# Reporte de Clasificación:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        18
#            1       1.00      1.00      1.00        27
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
nuevo = np.array([[0.5, -1.2]])  # ejemplo
pred = clf.predict(nuevo)

print("Paciente nuevo:", nuevo)
print("Clasificación:", "Clase 1" if pred[0]==1 else "Clase 0")
# Out:
# Paciente nuevo: [[ 0.5 -1.2]]
# Clasificación: Clase 1
